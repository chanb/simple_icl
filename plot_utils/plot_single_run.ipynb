# %%
import _pickle as pickle
import matplotlib.pyplot as plt
import numpy as np

# %%
result_path = "/Users/chanb/research/ualberta/simple_icl/experiments/evaluation_results/default-09-14-24_17_26_39-ea73efde-e856-42fd-92cf-eadcadc3fe29.pkl"
result_path = "/Users/chanb/research/ualberta/simple_icl/experiments/evaluation_results/default-09-14-24_17_38_23-ecc5711f-6fba-49e7-8338-c09db4fb49a1.pkl"
result_path = "/Users/chanb/research/ualberta/simple_icl/experiments/evaluation_results/default-09-14-24_17_46_26-301a351d-c721-4518-8ace-38e972d6a2c9.pkl"
result_path = "/Users/chanb/research/ualberta/simple_icl/experiments/evaluation_results/default-09-14-24_17_55_02-98e22302-d6ed-475a-a638-545aa4b88324.pkl"
result_path = "/Users/chanb/research/ualberta/simple_icl/experiments/evaluation_results/default-09-14-24_18_00_09-2ede5804-05ef-4d17-89e1-d7704f46269d.pkl"
result_path = "/Users/chanb/research/ualberta/simple_icl/experiments/evaluation_results/default-09-14-24_18_09_35-446bb86a-c173-4767-b72f-4c7d7c06137e.pkl"
result_path = "/Users/chanb/research/ualberta/simple_icl/experiments/evaluation_results/default-09-14-24_18_16_22-cf8e3528-92b0-4d06-a37e-0593ce041990.pkl"
result_path = "/Users/chanb/research/ualberta/simple_icl/experiments/evaluation_results/default-09-14-24_18_24_33-9ce13169-e53b-43f0-9505-8af09a8bfb8e.pkl"
result_path = "/Users/chanb/research/ualberta/simple_icl/experiments/evaluation_results/default-09-14-24_18_39_00-0d6b0799-3b2a-4a59-ad26-389cd1aa583f.pkl"
result_path = "/Users/chanb/research/ualberta/simple_icl/experiments/evaluation_results/default-09-14-24_18_46_33-5a396773-b6b7-4e27-837d-085a01a78906.pkl"
result_path = "/Users/chanb/research/ualberta/simple_icl/experiments/evaluation_results/default-09-14-24_19_01_58-f37ddd15-a0e0-4d74-b574-ab89895f879c.pkl"
result_path = "/Users/chanb/research/ualberta/simple_icl/experiments/evaluation_results/default-09-14-24_19_15_25-d55aea7f-9ae9-4816-958a-5a81b446927c.pkl"
result_path = "/Users/chanb/research/ualberta/simple_icl/experiments/evaluation_results/default-09-14-24_19_21_31-5dbe321c-740e-49ce-944a-234fc9f81481.pkl"
result_path = "/Users/chanb/research/ualberta/simple_icl/experiments/evaluation_results/default-09-14-24_19_26_14-90bd51bb-3ca0-44f7-a630-29847958ccc7.pkl"
result_path = "/Users/chanb/research/ualberta/simple_icl/experiments/evaluation_results/default-09-14-24_19_34_02-5bbd18fa-3a58-443a-84fe-9956983ba1c5.pkl"
result_path = "/Users/chanb/research/ualberta/simple_icl/experiments/evaluation_results/default-09-14-24_20_02_38-74ac8214-54e6-4bd1-ac78-625ce5597036.pkl"
result_path = "/Users/chanb/research/ualberta/simple_icl/experiments/evaluation_results/default-09-14-24_20_29_29-b02b5e03-bfdd-4dc2-9440-eb723e9450f9.pkl"
result_path = "/Users/chanb/research/ualberta/simple_icl/experiments/evaluation_results/default-09-14-24_20_54_06-b1c40c66-f17c-47fd-997d-b4dbeec49abe.pkl"
result_path = "/Users/chanb/research/ualberta/simple_icl/experiments/evaluation_results/default-09-14-24_21_26_31-0c9b506e-7308-4059-9234-068bdc6e2f49.pkl"
result_path = "/Users/chanb/research/ualberta/simple_icl/experiments/evaluation_results/default-09-14-24_21_54_59-aee1ed0e-9aca-44f3-a357-863c46a16e78.pkl"
result_path = "/Users/chanb/research/ualberta/simple_icl/experiments/evaluation_results/ic-09-15-24_08_16_26-04de5caf-ecc2-4180-8dde-2d8ef1eeae86.pkl"
result_path = "/Users/chanb/research/ualberta/simple_icl/experiments/evaluation_results/iw-09-15-24_07_54_44-7736e4a9-fce0-4ac1-ba2d-cf449e158c69.pkl"
result_path = "/Users/chanb/research/ualberta/icl/simple_icl/experiments/evaluation_results/default-09-15-24_09_01_33-7914db09-b55a-4517-a518-1ad63c1a89fa.pkl"
result_path = "/Users/chanb/research/ualberta/icl/simple_icl/experiments/evaluation_results/ic-09-15-24_09_07_32-526970f8-2a2a-47c9-b355-f2cbec7631f2.pkl"
result_path = "/Users/chanb/research/ualberta/icl/simple_icl/experiments/evaluation_results/iw-09-15-24_09_16_52-94da26d9-102d-4625-a33c-c3d841c8f8cf.pkl"
result_path = "/Users/chanb/research/ualberta/icl/cc_results/paper_experiments/evaluation_results/omniglot-input_noise/dataset_size_1000000-p_relevant_context_0.9-input_noise_std_1.0-seed_2-09-25-24_22_38_28-936cc85c-8f0d-49c3-8d6b-909dfd312b8c.pkl"
result_path = "/Users/chanb/research/ualberta/icl/cc_results/paper_experiments/evaluation_results/omniglot-input_noise/dataset_size_100000-p_relevant_context_0.9-input_noise_std_1.0-seed_2-09-25-24_22_22_08-c8770314-e025-4d4e-8925-6cbbc75211f1.pkl"
data = pickle.load(open(result_path, "rb"))

# %%
data.keys()

# %%
start_ind = 0
end_ind = 502

# %%
for eval_key in data["stats"]:
    if "flip_label" not in eval_key:
        continue
    plt.plot(
        data["checkpoint_steps"][start_ind:end_ind],
        data["stats"][eval_key]["loss"][start_ind:end_ind],
        label=eval_key
    )
plt.legend()
plt.show()

for eval_key in data["stats"]:
    if "flip_label" in eval_key:
        continue
    plt.plot(
        data["checkpoint_steps"][start_ind:end_ind],
        data["stats"][eval_key]["loss"][start_ind:end_ind],
        label=eval_key
    )
plt.legend()
plt.show()


for eval_key in data["stats"]:
    if "flip_label" in eval_key or "eval-relevant" not in eval_key:
        continue
    plt.plot(
        data["checkpoint_steps"][start_ind:end_ind],
        data["stats"][eval_key]["loss"][start_ind:end_ind],
        label=eval_key
    )
plt.legend()
plt.show()

for eval_key in data["stats"]:
    if "flip_label" in eval_key or "eval-irrelevant" not in eval_key:
        continue
    plt.plot(
        data["checkpoint_steps"][start_ind:end_ind],
        data["stats"][eval_key]["loss"][start_ind:end_ind],
        label=eval_key
    )
plt.legend()
plt.show()


for eval_key in data["stats"]:
    if "flip_label" not in eval_key or "eval-relevant" not in eval_key:
        continue
    plt.plot(
        data["checkpoint_steps"][start_ind:end_ind],
        data["stats"][eval_key]["loss"][start_ind:end_ind],
        label=eval_key
    )
plt.legend()
plt.show()

for eval_key in data["stats"]:
    if "flip_label" not in eval_key or "eval-irrelevant" not in eval_key:
        continue
    plt.plot(
        data["checkpoint_steps"][start_ind:end_ind],
        data["stats"][eval_key]["loss"][start_ind:end_ind],
        label=eval_key
    )
plt.legend()
plt.show()

plt.plot(
        data["checkpoint_steps"][start_ind:end_ind],
        data["stats"]["pretraining"]["loss"][start_ind:end_ind],
        label="train"
    )
plt.plot(
        data["checkpoint_steps"][start_ind:end_ind],
        data["stats"]["eval-default-none"]["loss"][start_ind:end_ind],
        label="test"
    )
plt.legend()
plt.show()

# %%
data["stats"]["pretraining"]["loss"][100], data["checkpoint_steps"][100]

# %%
print(len(data["checkpoint_steps"]))

# %%
for eval_key in data["stats"]:
    if "flip_label" not in eval_key:
        continue
    plt.plot(
        data["checkpoint_steps"][start_ind:end_ind],
        data["stats"][eval_key]["accuracy"][start_ind:end_ind],
        label=eval_key
    )
plt.ylim(-1.0, 101.0)
plt.legend()
plt.show()

for eval_key in data["stats"]:
    if "flip_label" in eval_key:
        continue
    plt.plot(
        data["checkpoint_steps"][start_ind:end_ind],
        data["stats"][eval_key]["accuracy"][start_ind:end_ind],
        label=eval_key
    )
plt.ylim(-1.0, 101.0)
plt.legend()
plt.show()


for eval_key in data["stats"]:
    if "flip_label" in eval_key or "eval-relevant" not in eval_key:
        continue
    plt.plot(
        data["checkpoint_steps"][start_ind:end_ind],
        data["stats"][eval_key]["accuracy"][start_ind:end_ind],
        label=eval_key
    )
plt.ylim(-1.0, 101.0)
plt.legend()
plt.show()

for eval_key in data["stats"]:
    if "flip_label" in eval_key or "eval-irrelevant" not in eval_key:
        continue
    plt.plot(
        data["checkpoint_steps"][start_ind:end_ind],
        data["stats"][eval_key]["accuracy"][start_ind:end_ind],
        label=eval_key
    )
plt.ylim(-1.0, 101.0)
plt.legend()
plt.show()


for eval_key in data["stats"]:
    if "flip_label" not in eval_key or "eval-relevant" not in eval_key:
        continue
    plt.plot(
        data["checkpoint_steps"][start_ind:end_ind],
        data["stats"][eval_key]["accuracy"][start_ind:end_ind],
        label=eval_key
    )
plt.ylim(-1.0, 101.0)
plt.legend()
plt.show()

for eval_key in data["stats"]:
    if "flip_label" not in eval_key or "eval-irrelevant" not in eval_key:
        continue
    plt.plot(
        data["checkpoint_steps"][start_ind:end_ind],
        data["stats"][eval_key]["accuracy"][start_ind:end_ind],
        label=eval_key
    )
plt.ylim(-1.0, 101.0)
plt.legend()
plt.show()

plt.plot(
        data["checkpoint_steps"][start_ind:end_ind],
        data["stats"]["pretraining"]["accuracy"][start_ind:end_ind],
    )
plt.ylim(-1.0, 101.0)
plt.legend()
plt.show()

# %%
for eval_key in data["stats"]:
    if "flip_label" not in eval_key:
        continue
    plt.plot(
        data["checkpoint_steps"][start_ind:end_ind],
        data["stats"][eval_key]["context contains query class"][start_ind:end_ind],
        label=eval_key
    )
plt.legend()
plt.show()

for eval_key in data["stats"]:
    if "flip_label" in eval_key:
        continue
    plt.plot(
        data["checkpoint_steps"][start_ind:end_ind],
        data["stats"][eval_key]["context contains query class"][start_ind:end_ind],
        label=eval_key
    )
plt.legend()
plt.show()


for eval_key in data["stats"]:
    if "flip_label" in eval_key or "eval-relevant" not in eval_key:
        continue
    plt.plot(
        data["checkpoint_steps"][start_ind:end_ind],
        data["stats"][eval_key]["context contains query class"][start_ind:end_ind],
        label=eval_key
    )
plt.legend()
plt.show()

for eval_key in data["stats"]:
    if "flip_label" in eval_key or "eval-irrelevant" not in eval_key:
        continue
    plt.plot(
        data["checkpoint_steps"][start_ind:end_ind],
        data["stats"][eval_key]["context contains query class"][start_ind:end_ind],
        label=eval_key
    )
plt.legend()
plt.show()


for eval_key in data["stats"]:
    if "flip_label" not in eval_key or "eval-relevant" not in eval_key:
        continue
    plt.plot(
        data["checkpoint_steps"][start_ind:end_ind],
        data["stats"][eval_key]["context contains query class"][start_ind:end_ind],
        label=eval_key
    )
plt.legend()
plt.show()

for eval_key in data["stats"]:
    if "flip_label" not in eval_key or "eval-irrelevant" not in eval_key:
        continue
    plt.plot(
        data["checkpoint_steps"][start_ind:end_ind],
        data["stats"][eval_key]["context contains query class"][start_ind:end_ind],
        label=eval_key
    )
plt.legend()
plt.show()

plt.plot(
        data["checkpoint_steps"][start_ind:end_ind],
        data["stats"]["pretraining"]["context contains query class"][start_ind:end_ind],
    )
plt.legend()
plt.show()
